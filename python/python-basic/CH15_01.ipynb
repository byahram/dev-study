# %%
'''
2025.04.22 화

예제 1 : 뉴스 제목 + 링크 + 이미지 크롤링
'''

'''
[필요한 라이브러리]
'''
import requests                      # 웹 요청을 보내는 라이브러리
from bs4 import BeautifulSoup       # HTML 파싱을 위한 라이브러리

# 크롤링 대상 URL (네이버 뉴스 > 생활/문화 섹션)
url = "https://news.naver.com/section/103"

# 브라우저처럼 보이기 위한 헤더 설정 (봇 차단 방지용)
headers = {
    "User-Agent" : "Mozilla/5.0"
}

# Http GET 요청을 보내기
res = requests.get(url, headers = headers)

# 받은 HTML 문서를 파싱하여 soup 객체 생성
soup = BeautifulSoup(res.text, "lxml")


'''
[soup.select("css 선택자")]

- html문서 안에서 css 선택자 문법을 써서 원하는 요소들을 리스트 형태로 가져옴
- 결과는 항상 리스트로 변환
'''

# 뉴스 제목과 링크가 포함된 'a' 태그들 선택 (class 속성에 'sa_text_title' 포함)
news_list = soup.select("a.sa_text_title")


'''
[각 뉴스 항목 순회]

- start = 1 : enumerate()는 인덱스를 0부터 시작하는데, start = 1 1부터 시작해 달라는 뜻
'''
for i, a_tag in enumerate(news_list, start = 1) :

    '''
    [뉴스 제목 텍스트 추출(공백 제거)]

    - tag.get_text(strip = False, True)
    - False라면 공백을 지워주지 않음
    - True라면 공백을 지준다.
    '''
    title = a_tag.get_text(strip = True)

    
    '''
    [뉴스 기사 링크 추출 (a 태그의 href 속성)]
    '''
    link = a_tag["href"]

    
    '''
    [뉴스 이미지 추출]

    - 현재 'a' 태그의 부모 요소 중 'li' 태그를 찾음
    - find_parent() : 특정 태그의 부모 태그를 찾아주는 기능 > 태그의 한 단계 위 부모 찾기
    - find_parents() : 태그의 모든 조상들 찾기(리스트)

    [li 태그 안에 있는 img 태그 찾기]

    - (있을 경우에만)
    - soup.select_one("img") : BeautifulSoup에서 사용하는 함수고, "처음 나오는 하나의 요소"만 선택
    - soup.select("img") -> 리스트로 가져온다.
    '''
    parent_li = a_tag.find_parent("li")

    img_tag = parent_li.select_one("img") if parent_li else None

    
    '''
    [뉴스 이미지 URL 추출]

    1. 이미지가 자연 로딩 방식이면 data-src 속성 사용
        - data-src : 자바스크립트나 크롤러가 데이터를 읽을 때 사용
        - html에서 사용자 정의 속성을 만들 때 사용
    2. 일반적인 경우에는 src 속성 사용
        - img_tag라는 이미지 태그가 존재하고, 그 태그에 src 속성이 있으면, 그 src 속성의 값을 img_url이라는 변수에 저장하라는 의미이다.
    3. 이미지가 없는 경우
    '''
    if img_tag and img_tag.has_attr("data-src") :
        img_url = img_tag["data-src"]
    elif img_tag and img_tag.has_attr("src") :
        img_url = img_tag["src"]
    else :
        img_url = "이미지 없음"

    # 결과 출력
    print(f"{i}. {title}")    # 번호와 뉴스 제목
    print(f"> {link}")        # 뉴스 상세 페이지 url
    print(f"> {img_url}")     # 이미지 url 또는 '이미지 없음'
    # 구분선
    print("---")
# Out:
# 1. 현대차 '2025 코나' 출시 판매…최저 2천400만 원부터
# > https://n.news.naver.com/mnews/article/374/0000436740
# > https://mimgnews.pstatic.net/image/origin/374/2025/04/23/436740.jpg?type=nf220_150
# ---
# 2. 광주·전남 140여개 본당, 프란치스코 교황 '추모 미사'
# > https://mimgnews.pstatic.net/image/origin/296/2025/04/23/88882.jpg?type=nf220_150
# ---
# 31. "연휴에 홍콩 가요"…30대 직장인, 해외여행 고집하는 이유
# > https://n.news.naver.com/mnews/article/015/0005122941
# > https://mimgnews.pstatic.net/image/origin/015/2025/04/23/5122941.jpg?type=nf220_150
# ---
# 32. 김호중처럼 '술타기' 했다간…6월부터 최대 2000만원 벌금
# > https://n.news.naver.com/mnews/article/025/0003436101
# > https://mimgnews.pstatic.net/image/origin/025/2025/04/23/3436101.jpg?type=nf220_150
# ---
# 33. 혼수 상태 환자여도 뇌는 회복을 준비하고 있답니다
# > https://n.news.naver.com/mnews/article/047/0002470794
# > https://mimgnews.pstatic.net/image/origin/047/2025/04/23/2470794.jpg?type=nf220_150
# ---
# 34. 이틀째 교황 추모 행렬..."신자 아닌데도 왔어요"
# > https://n.news.naver.com/mnews/article/052/0002184069
# > https://mimgnews.pstatic.net/image/origin/052/2025/04/23/2184069.jpg?type=nf220_150
# ---
# 35. [날씨] 비 그친 뒤 기온 '쑥'…큰 일교차 건강관리 유의
# > https://n.news.naver.com/mnews/article/422/0000733833
# > https://mimgnews.pstatic.net/image/origin/422/2025/04/23/733833.jpg?type=nf220_150
# ---
# 36. “차 팔러 조기축구회 갔는데 말도 못 꺼내”…車 4000대 판매한 ‘마스터’의 사연은
# > https://n.news.naver.com/mnews/article/009/0005481132
# > https://mimgnews.pstatic.net/image/origin/009/2025/04/23/5481132.jpg?type=nf220_150
# ---
# 37. 걸리면 치사율 50% ‘이 감염균’…올해도 빨리 찾아왔다
# > https://n.news.naver.com/mnews/article/016/0002461565
# > https://mimgnews.pstatic.net/image/origin/016/2025/04/23/2461565.jpg?type=nf220_150
# ---
# 38. 서울국제도서전 '사유화 반대' 논란… 출협 "오해 바로잡겠다"
# > https://n.news.naver.com/mnews/article/079/0004016784
# > https://mimgnews.pstatic.net/image/origin/079/2025/04/23/4016784.jpg?type=nf220_150
# ---
# 39. “일찍 자야 공부도 잘 한다” 잔소리 사실이었네
# > https://n.news.naver.com/mnews/article/081/0003535860
# > https://mimgnews.pstatic.net/image/origin/081/2025/04/23/3535860.jpg?type=nf220_150
# ---
# 40. [날씨] 오늘 낮 동안 다시 따뜻한 봄...큰 기온변화 유의
# > https://n.news.naver.com/mnews/article/052/0002184048
# > https://mimgnews.pstatic.net/image/origin/052/2025/04/23/2184048.jpg?type=nf220_150
# ---
# 41. [센터웨더] 비구름 물러가고 25도 따뜻…큰 일교차에 감기 주의
# > https://n.news.naver.com/mnews/article/422/0000733819
# > https://mimgnews.pstatic.net/image/origin/422/2025/04/23/733819.jpg?type=nf220_150
# ---
# 42. [이인숙의 옛그림 예찬] <295>사람인 듯 짐승인 듯 천둥번개의 벼락신 뇌공(雷公)
# > https://n.news.naver.com/mnews/article/088/0000943669
# > https://mimgnews.pstatic.net/image/origin/088/2025/04/23/943669.jpg?type=nf220_150
# ---
# 43. 고혈압, 전 단계 "왜 이리 많아"…뇌 건강 위해 ‘이 습관’ 꼭 필요한 이유?
# > https://n.news.naver.com/mnews/article/296/0000088880
# > https://mimgnews.pstatic.net/image/origin/296/2025/04/23/88880.jpg?type=nf220_150
# ---
